# %% [markdown]
# ## Pyspark withColumn and selectExpr

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext
spark = SparkSession.builder.appName("practice-Hexaware").getOrCreate()

# %%
df2 = spark.read.csv("Marks_data.csv",header = True,inferSchema = True)
df2.show()
type(df2)
df2.columns
# Out:
# +----+--------+--------+---+
# |Name|M1 Score|M2 Score|age|
# +----+--------+--------+---+
# |Alex|      62|      80| 20|
# |Brad|      45|      56| 19|
# |Joey|      85|      98| 21|
# |NULL|      54|      79| 20|
# |abhi|    NULL|    NULL| 20|
# +----+--------+--------+---+
# ['Name', 'M1 Score', 'M2 Score', 'age']

# %%
files = ['Marks_data.csv', 'Marks_data.csv']
df3 = spark.read.csv(files, sep = ',' ,  inferSchema=True, header=True)
print(type(df3))
# df1 = csv_file.toPandas()
# Out:
# <class 'pyspark.sql.classic.dataframe.DataFrame'>

# %%
df = spark.read.text("1.txt")
df.selectExpr("split(value, ' ') as Text_Data_In_Rows_Using_Text").show(7, False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------+
# |Text_Data_In_Rows_Using_Text                                                                                              |
# +--------------------------------------------------------------------------------------------------------------------------+
# |[this, is, a, text, file, i, created, to, check, the, pyspark, "txt_file, =, spark.read.text("example.txt")", command...!]|
# +--------------------------------------------------------------------------------------------------------------------------+

# %%
from pyspark.sql.functions import concat_ws
df2.withColumn ("Marks scored", concat_ws(",", "M1 Score", 'M2 Score')).show()
# Out:
# +----+--------+--------+---+------------+
# |Name|M1 Score|M2 Score|age|Marks scored|
# +----+--------+--------+---+------------+
# |Alex|      62|      80| 20|       62,80|
# |Brad|      45|      56| 19|       45,56|
# |Joey|      85|      98| 21|       85,98|
# |NULL|      54|      79| 20|       54,79|
# |abhi|    NULL|    NULL| 20|            |
# +----+--------+--------+---+------------+

# %%
# importing module
import pyspark
# import lit function
from pyspark.sql.functions import lit
# importing sparksession from pyspark.sql module
from pyspark.sql import SparkSession
# creating sparksession and giving an app name
spark = SparkSession.builder.appName('sparkdf').getOrCreate()
# list of employee data
data = [["1", "sravan", "company 1"],
["2", "ojaswi", "company 1"],
["3", "rohith", "company 2"],
["4", "sridevi", "company 1"],
["5", "bobby", "company 1"]]
# specify column names
columns = ['ID', 'NAME', 'Company']
# creating a dataframe from the lists of data
df = spark.createDataFrame(data, columns)
#adding new columns

df.withColumn("salary",lit(30000)).show()
# Out:
# +---+-------+---------+------+
# | ID|   NAME|  Company|salary|
# +---+-------+---------+------+
# |  1| sravan|company 1| 30000|
# |  2| ojaswi|company 1| 30000|
# |  3| rohith|company 2| 30000|
# |  4|sridevi|company 1| 30000|
# |  5|  bobby|company 1| 30000|
# +---+-------+---------+------+

# %%
# Add a column named salary from ID column with multiply of 2300
df.withColumn("salary", df.ID*2300).show()
# Out:
# +---+-------+---------+------+
# | ID|   NAME|  Company|salary|
# +---+-------+---------+------+
# |  1| sravan|company 1|  2300|
# |  2| ojaswi|company 1|  4600|
# |  3| rohith|company 2|  6900|
# |  4|sridevi|company 1|  9200|
# |  5|  bobby|company 1| 11500|
# +---+-------+---------+------+

# %%
# Next one --dataframe.withColumn(“column_name”, concat_ws(“Separator”,”existing_column1″,’existing_column2′))

# add salary column by checking its existence

if 'salary' not in df.columns:
    df.withColumn("salary", lit(34000)).show()
# Out:
# +---+-------+---------+------+
# | ID|   NAME|  Company|salary|
# +---+-------+---------+------+
# |  1| sravan|company 1| 34000|
# |  2| ojaswi|company 1| 34000|
# |  3| rohith|company 2| 34000|
# |  4|sridevi|company 1| 34000|
# |  5|  bobby|company 1| 34000|
# +---+-------+---------+------+

# %% [markdown]
# ## Transformations and actions

# %%
import pyspark

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()

count_rdd = sc.parallelize([1,2,3,4,5,6,7,8,9])
print(count_rdd.collect())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(count_rdd.count())
# Out:
# 9

# %%
print(count_rdd.first())
# Out:
# 1

# %%
print(count_rdd.take(7))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
reduce_rdd = count_rdd.reduce(lambda x, y: x + y)

# %%
print(reduce_rdd)
# Out:
# 45

# %%
count_rdd.saveAsTextFile('3.txt')
