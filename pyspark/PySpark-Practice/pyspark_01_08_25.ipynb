# %%
import pyspark
# import lit function
from pyspark.sql.functions import lit
# importing sparksession from pyspark.sql module
from pyspark.sql import SparkSession
# creating sparksession and giving an app name
spark = SparkSession.builder.appName('sparksql').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/01 10:13:12 WARN Utils: Your hostname, apples-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.18.169 instead (on interface en0)
# 25/08/01 10:13:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/01 10:13:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Spark sql
# spark -shell
df = spark.read.option("header",True).csv("Marks_data.csv")
df.printSchema()
df.show()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- M1 Score: string (nullable = true)
#  |-- M2 Score: string (nullable = true)
#  |-- age: string (nullable = true)
#
# +----+--------+--------+---+
# |Name|M1 Score|M2 Score|age|
# +----+--------+--------+---+
# |Alex|      62|      80| 20|
# |Brad|      45|      56| 19|
# |Joey|      85|      98| 21|
# |NULL|      54|      79| 20|
# |abhi|    NULL|    NULL| 20|
# +----+--------+--------+---+
